# %%
import pandas as pd

# %%
train = pd.read_csv("california-house-prices/train.csv")

# %%
train.head()
# Out:
#    Id            Address  Sold Price  \
# 0   0        540 Pine Ln   3825000.0
# 1   1     1727 W 67th St    505000.0
# 2   2     28093 Pine Ave    140000.0
# 3   3  10750 Braddock Dr   1775000.0
# 4   4  7415 O Donovan Rd   1175000.0
#
#                                              Summary          Type  \
# 0  540 Pine Ln, Los Altos, CA 94022 is a single f...  SingleFamily
# 1  HURRY, HURRY.......Great house 3 bed and 2 bat...  SingleFamily
# 2  'THE PERFECT CABIN TO FLIP!  Strawberry deligh...  SingleFamily
# 3  Rare 2-story Gated 5 bedroom Modern Mediterran...  SingleFamily
# 4  Beautiful 200 acre ranch land with several pas...    VacantLand
#
#    Year built                                       Heating  \
# 0      1969.0  Heating - 2+ Zones, Central Forced Air - Gas
# 1      1926.0                                   Combination
# 2      1958.0                                    Forced air
# 3      1947.0                                       Central
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47439 entries, 0 to 47438
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           47439 non-null  int64
#  1   Address                      47439 non-null  object
#  2   Sold Price                   47439 non-null  float64
#  3   Summary                      47089 non-null  object
#  4   Type                         47439 non-null  object
#  5   Year built                   46394 non-null  float64
#  6   Heating                      40974 non-null  object
#  7   Cooling                      36817 non-null  object
#  8   Parking                      46531 non-null  object
#  9   Lot                          33258 non-null  float64
#  10  Bedrooms                     44567 non-null  object
#  11  Bathrooms                    43974 non-null  float64
# ...

# %%
train.isna().sum().sort_values(ascending=True)
# Out:
# Id                                 0
# City                               0
# Listed Price                       0
# Listed On                          0
# Zip                                0
# State                              0
# Address                            0
# Sold Price                         0
# Type                               0
# Region                             2
# Summary                          350
# Parking                          908
# Total spaces                     916
# Garage spaces                    917
# Year built                      1045
# Total interior livable area     2526
# Bedrooms                        2872
# Bathrooms                       3465
# Tax assessed value              3652
# Parking features                4308
# Annual tax amount               4310
# Elementary School               4742
# Elementary School Distance      4742
# Elementary School Score         4896
# High School                     5000
# ...

# %%
adres = train['Address']

# %%
from googlemaps import Client as GoogleMaps
import googlemaps
import gmaps

# %%
gmaps = googlemaps.Client(key='') # Api geocoding key

# %%
addres = train['Address']
# Out:
# '922 E Channel St'

# %%
latitude = []
longitude = []

# %%
train['complet_addres'] = train['Address'] +', '+ train['City'] + ', '+train['State'] +" "+train['Zip'].astype("str")

# %%
train['complet_addres']

# %%
train["new_add"] = train['complet_addres'].apply(gmaps.geocode)

# %%
def lat(x):
    if len(x)>0:
        return  x[0]['geometry']['location']['lat']

# %%
def long(x):
    if len(x)>0:
        return x[0]['geometry']['location']['lng']

# %%
train_v2 = train_v1.drop(columns='latitude')

# %%
train_v2['latitude'] = train_v2['new_add'].apply(lat)
train_v2['longitude'] = train_v2['new_add'].apply(long)

# %%
train_v2.isna().sum().sort_values()
# Out:
# Id                                 0
# Address                            0
# Sold Price                         0
# new_add                            0
# Type                               0
# complet_addres                     0
# State                              0
# Zip                                0
# City                               0
# Listed Price                       0
# Listed On                          0
# latitude                           1
# longitude                          1
# Region                             2
# Summary                          350
# Parking                          908
# Total spaces                     916
# Garage spaces                    917
# Year built                      1045
# Total interior livable area     2526
# Bedrooms                        2872
# Bathrooms                       3465
# Tax assessed value              3652
# Parking features                4308
# Annual tax amount               4310
# ...

# %%
train_v2.to_csv("california-house-prices/train_geo.csv")

# %%
train_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47439 entries, 0 to 47438
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           47439 non-null  int64
#  1   Address                      47439 non-null  object
#  2   Sold Price                   47439 non-null  float64
#  3   Summary                      47089 non-null  object
#  4   Type                         47439 non-null  object
#  5   Year built                   46394 non-null  float64
#  6   Heating                      40974 non-null  object
#  7   Cooling                      36817 non-null  object
#  8   Parking                      46531 non-null  object
#  9   Lot                          33258 non-null  float64
#  10  Bedrooms                     44567 non-null  object
#  11  Bathrooms                    43974 non-null  float64
# ...
